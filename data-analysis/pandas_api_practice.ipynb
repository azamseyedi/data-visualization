# %%
import pandas as pd

# %%
data = {
    "Name": ["Sara", "Ali", "Nina", "Reza", "Mina"],
    "Age": [25, 31, 22, 40, 29],
    "City": ["Oslo", "Trondheim", "Oslo", "Bergen", "Trondheim"],
    "Salary": [45000, 52000, 39000, 61000, 48000]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    Name  Age       City  Salary
# 0  Sara   25       Oslo   45000
# 1   Ali   31  Trondheim   52000
# 2  Nina   22       Oslo   39000
# 3  Reza   40     Bergen   61000
# 4  Mina   29  Trondheim   48000

# %%
df.head(5)
# Out:
#    Name  Age       City  Salary
# 0  Sara   25       Oslo   45000
# 1   Ali   31  Trondheim   52000
# 2  Nina   22       Oslo   39000
# 3  Reza   40     Bergen   61000
# 4  Mina   29  Trondheim   48000

# %%
df.head(5)  # 5 ردیف اول
df.tail(2)  # 2 ردیف آخر
# Out:
#    Name  Age       City  Salary
# 3  Reza   40     Bergen   61000
# 4  Mina   29  Trondheim   48000

# %%
df.head(5)
df.tail(2)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      str
#  1   Age     5 non-null      int64
#  2   City    5 non-null      str
#  3   Salary  5 non-null      int64
# dtypes: int64(2), str(2)
# memory usage: 292.0 bytes

# %%
df.columns       # نام ستون‌ها
# Out:
# Index(['Name', 'Age', 'City', 'Salary'], dtype='str')

# %%
df.index         # index ردیف‌ها
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.shape
# Out:
# (5, 4)

# %%
df.Salary
# Out:
# 0    45000
# 1    52000
# 2    39000
# 3    61000
# 4    48000
# Name: Salary, dtype: int64

# %%
df[["City", "Name"]]
# Out:
#         City  Name
# 0       Oslo  Sara
# 1  Trondheim   Ali
# 2       Oslo  Nina
# 3     Bergen  Reza
# 4  Trondheim  Mina

# %%
df[["Age", "Name", "Salary"]]
# Out:
#    Age  Name  Salary
# 0   25  Sara   45000
# 1   31   Ali   52000
# 2   22  Nina   39000
# 3   40  Reza   61000
# 4   29  Mina   48000

# %%
result = df[df["Age"] > 28]
print(result)
# Out:
#    Name  Age       City  Salary
# 1   Ali   31  Trondheim   52000
# 3  Reza   40     Bergen   61000
# 4  Mina   29  Trondheim   48000

# %%
result = df[df["City"] == "Oslo"]
print(result)
# Out:
#    Name  Age  City  Salary
# 0  Sara   25  Oslo   45000
# 2  Nina   22  Oslo   39000

# %%
result = df[df["Salary"] >= 50000]
print(result)
# Out:
#    Name  Age       City  Salary
# 1   Ali   31  Trondheim   52000
# 3  Reza   40     Bergen   61000

# %%
result = df[(df["Age"] > 25) & (df["City"] == "Trondheim")]
print(result)
# Out:
#    Name  Age       City  Salary
# 1   Ali   31  Trondheim   52000
# 4  Mina   29  Trondheim   48000

# %%
df_sorted = df.sort_values(by='Age')

print(df_sorted)
# Out:
#    Name  Age       City  Salary
# 2  Nina   22       Oslo   39000
# 0  Sara   25       Oslo   45000
# 4  Mina   29  Trondheim   48000
# 1   Ali   31  Trondheim   52000
# 3  Reza   40     Bergen   61000

# %%
df_sorted = df.sort_values(by='Age', ascending=False)

print(df_sorted)
# Out:
#    Name  Age       City  Salary
# 3  Reza   40     Bergen   61000
# 1   Ali   31  Trondheim   52000
# 4  Mina   29  Trondheim   48000
# 0  Sara   25       Oslo   45000
# 2  Nina   22       Oslo   39000

# %%
df_sorted = df.sort_values(by="Salary", ascending=False)
print(df_sorted)
# Out:
#    Name  Age       City  Salary
# 3  Reza   40     Bergen   61000
# 1   Ali   31  Trondheim   52000
# 4  Mina   29  Trondheim   48000
# 0  Sara   25       Oslo   45000
# 2  Nina   22       Oslo   39000

# %%
df_sorted.set_index("Name", inplace=False)
# Out:
#       Age       City  Salary
# Name
# Reza   40     Bergen   61000
# Ali    31  Trondheim   52000
# Mina   29  Trondheim   48000
# Sara   25       Oslo   45000
# Nina   22       Oslo   39000

# %%
df_sorted.set_index("City", inplace=False)
# Out:
#            Name  Age  Salary
# City
# Bergen     Reza   40   61000
# Trondheim   Ali   31   52000
# Trondheim  Mina   29   48000
# Oslo       Sara   25   45000
# Oslo       Nina   22   39000

# %%
df_sorted.set_index("Name", inplace=False)
# Out:
#       Age       City  Salary
# Name
# Reza   40     Bergen   61000
# Ali    31  Trondheim   52000
# Mina   29  Trondheim   48000
# Sara   25       Oslo   45000
# Nina   22       Oslo   39000

# %%
df_indexed = df_sorted.set_index("Name", inplace=False)

# %%
df_indexed
# Out:
#       Age       City  Salary
# Name
# Reza   40     Bergen   61000
# Ali    31  Trondheim   52000
# Mina   29  Trondheim   48000
# Sara   25       Oslo   45000
# Nina   22       Oslo   39000

# %%
ali_info = df_indexed.loc["Ali"]

print(ali_info)
# Out:
# Age              31
# City      Trondheim
# Salary        52000
# Name: Ali, dtype: object

# %%
df_indexed.loc["Ali", "Salary"]
# Out:
# np.int64(52000)

# %%
df_indexed.loc["Mina", ["Age","City"]]
# Out:
# Age            29
# City    Trondheim
# Name: Mina, dtype: object

# %%
df_indexed.iloc[0]
# Out:
# Age           40
# City      Bergen
# Salary     61000
# Name: Reza, dtype: object

# %%
df_indexed.iloc[0, 1]
# Out:
# 'Bergen'

# %%
Salary_in_the_third_arrow = df_indexed.iloc[2, 2]
print(Salary_in_the_third_arrow)
# Out:
# 48000

# %%
df_indexed.iloc[1, [0, 2]]
# Out:
# Age          31
# Salary    52000
# Name: Ali, dtype: int64

# %%
df_indexed.iloc[1:4]
# Out:
#       Age       City  Salary
# Name
# Ali    31  Trondheim   52000
# Mina   29  Trondheim   48000
# Sara   25       Oslo   45000

# %%
df_indexed.iloc[1:4, 0:2]
# Out:
#       Age       City
# Name
# Ali    31  Trondheim
# Mina   29  Trondheim
# Sara   25       Oslo

# %%
numbers = list(range(1, 6))

# %%
years = list(range(1990, 2014))
print(years)
# Out:
# [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %%
years = list(map(str, range(1990, 2014)))
print(years)
# Out:
# ['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013']

# %%
import pandas as pd

data = {
    "Year": [2019, 2020, 2021, 2022, 2023, 2024],
    "Laptop": [120, 150, 180, 210, 260, 310],
    "Phone": [200, 230, 190, 270, 320, 370],
    "Tablet": [80, 95, 110, 105, 140, 160]
}

df = pd.DataFrame(data)

df
# Out:
#    Year  Laptop  Phone  Tablet
# 0  2019     120    200      80
# 1  2020     150    230      95
# 2  2021     180    190     110
# 3  2022     210    270     105
# 4  2023     260    320     140
# 5  2024     310    370     160

# %%
df[df["Year"]==2020]
# Out:
#    Year  Laptop  Phone  Tablet
# 1  2020     150    230      95

# %%
sales_2024=df[df["Year"]==2024]

# %%
sales_2024[["Laptop","Phone","Tablet"]]
# Out:
#    Laptop  Phone  Tablet
# 5     310    370     160

# %%
sales_2024[["Laptop","Phone","Tablet"]].iloc[0]
# Out:
# Laptop    310
# Phone     370
# Tablet    160
# Name: 5, dtype: int64

# %%
sales_2024[["Laptop", "Phone", "Tablet"]].iloc[0, 1]
# Out:
# np.int64(370)

# %%
sales_2024[["Laptop", "Phone", "Tablet"]].iloc[0, 2]
# Out:
# np.int64(160)

# %%
df[df["Year"]==2022][["Laptop","Phone","Tablet"]].iloc[0, 1]
# Out:
# np.int64(270)

# %%
df.iloc[3, 2]
# Out:
# np.int64(270)

# %%
df.iloc[2:4, 2:5]
# Out:
#    Phone  Tablet
# 2    190     110
# 3    270     105

# %%
df.iloc[1:4, 2:4]
# Out:
#    Phone  Tablet
# 1    230      95
# 2    190     110
# 3    270     105

# %%
df.iloc[2:5, 0:3]
# Out:
#    Year  Laptop  Phone
# 2  2021     180    190
# 3  2022     210    270
# 4  2023     260    320

# %%
df.loc[3, "Phone"]
# Out:
# np.int64(270)

# %%
df.loc[4, "Laptop"]
# Out:
# np.int64(260)

# %%
df.loc[2:4, ["Laptop", "Phone"]]
# Out:
#    Laptop  Phone
# 2     180    190
# 3     210    270
# 4     260    320

# %%
df.loc[1:3, ["Phone", "Tablet"]]
# Out:
#    Phone  Tablet
# 1    230      95
# 2    190     110
# 3    270     105

# %%
df.loc[df["Phone"]>250, ["Year","Phone"]]
# Out:
#    Year  Phone
# 3  2022    270
# 4  2023    320
# 5  2024    370

# %%
df.loc[df["Laptop"] > 200, ["Year", "Laptop"]]
# Out:
#    Year  Laptop
# 3  2022     210
# 4  2023     260
# 5  2024     310

# %%
df.loc[df["Tablet"] < 120, ["Year", "Tablet"]]
# Out:
#    Year  Tablet
# 0  2019      80
# 1  2020      95
# 2  2021     110
# 3  2022     105

# %%
df.loc[df["Phone"] >= 270, ["Year", "Phone", "Tablet"]]
# Out:
#    Year  Phone  Tablet
# 3  2022    270     105
# 4  2023    320     140
# 5  2024    370     160

# %%
df.sort_values("Laptop", ascending=True)
# Out:
#    Year  Laptop  Phone  Tablet
# 0  2019     120    200      80
# 1  2020     150    230      95
# 2  2021     180    190     110
# 3  2022     210    270     105
# 4  2023     260    320     140
# 5  2024     310    370     160

# %%
df.sort_values("Laptop", ascending=False)
# Out:
#    Year  Laptop  Phone  Tablet
# 5  2024     310    370     160
# 4  2023     260    320     140
# 3  2022     210    270     105
# 2  2021     180    190     110
# 1  2020     150    230      95
# 0  2019     120    200      80

# %%
df.sort_values("Tablet", ascending=False)
# Out:
#    Year  Laptop  Phone  Tablet
# 5  2024     310    370     160
# 4  2023     260    320     140
# 2  2021     180    190     110
# 3  2022     210    270     105
# 1  2020     150    230      95
# 0  2019     120    200      80

# %%
filtered = df[df["Phone"] >= 230]

filtered.sort_values("Phone", ascending=False)
# Out:
#    Year  Laptop  Phone  Tablet
# 5  2024     310    370     160
# 4  2023     260    320     140
# 3  2022     210    270     105
# 1  2020     150    230      95

# %%
df[df["Phone"] >= 230].sort_values("Phone", ascending=False)
# Out:
#    Year  Laptop  Phone  Tablet
# 5  2024     310    370     160
# 4  2023     260    320     140
# 3  2022     210    270     105
# 1  2020     150    230      95

# %%
df[df["Laptop"] > 150].sort_values("Tablet", ascending=True)
# Out:
#    Year  Laptop  Phone  Tablet
# 3  2022     210    270     105
# 2  2021     180    190     110
# 4  2023     260    320     140
# 5  2024     310    370     160

# %%
df.head()
# Out:
#    Year  Laptop  Phone  Tablet
# 0  2019     120    200      80
# 1  2020     150    230      95
# 2  2021     180    190     110
# 3  2022     210    270     105
# 4  2023     260    320     140

# %%
df.head(3)
# Out:
#    Year  Laptop  Phone  Tablet
# 0  2019     120    200      80
# 1  2020     150    230      95
# 2  2021     180    190     110

# %%
df.tail()
# Out:
#    Year  Laptop  Phone  Tablet
# 1  2020     150    230      95
# 2  2021     180    190     110
# 3  2022     210    270     105
# 4  2023     260    320     140
# 5  2024     310    370     160

# %%
df.tail(2)
# Out:
#    Year  Laptop  Phone  Tablet
# 4  2023     260    320     140
# 5  2024     310    370     160

# %%
df.head(4)
# Out:
#    Year  Laptop  Phone  Tablet
# 0  2019     120    200      80
# 1  2020     150    230      95
# 2  2021     180    190     110
# 3  2022     210    270     105

# %%
df.tail(3)
# Out:
#    Year  Laptop  Phone  Tablet
# 3  2022     210    270     105
# 4  2023     260    320     140
# 5  2024     310    370     160

# %%
df.shape
# Out:
# (6, 4)

# %%
df.columns
# Out:
# Index(['Year', 'Laptop', 'Phone', 'Tablet'], dtype='str')

# %%
df.columns
# Out:
# Index(['Year', 'Laptop', 'Phone', 'Tablet'], dtype='str')

# %%
df.columns
# Out:
# Index(['Year', 'Laptop', 'Phone', 'Tablet'], dtype='str')

# %%
df.shape      # چند ردیف و ستون؟
df.columns    # اسم ستون‌ها چیه؟
df.dtypes     # نوع داده‌ها چیه؟
# Out:
# Year      int64
# Laptop    int64
# Phone     int64
# Tablet    int64
# dtype: object

# %%
import pandas as pd

data = {
    "Name": ["Ali", "Sara", "Reza", "Mina"],
    "Age": [25, 30, None, 28],
    "Salary": [50000, None, 60000, 55000]
}

people = pd.DataFrame(data)

people
# Out:
#    Name   Age   Salary
# 0   Ali  25.0  50000.0
# 1  Sara  30.0      NaN
# 2  Reza   NaN  60000.0
# 3  Mina  28.0  55000.0

# %%
people["Age"].isnull().sum()
# Out:
# np.int64(1)

# %%
people.isnull().sum()
# Out:
# Name      0
# Age       1
# Salary    1
# dtype: int64

# %%
people.isnull().sum().sum()
# Out:
# np.int64(2)

# %%
people.isnull()
# Out:
#     Name    Age  Salary
# 0  False  False   False
# 1  False  False    True
# 2  False   True   False
# 3  False  False   False

# %%
people["Age"].mean()
# Out:
# np.float64(27.666666666666668)

# %%
people["Age"].fillna(people["Age"].mean())
# Out:
# 0    25.000000
# 1    30.000000
# 2    27.666667
# 3    28.000000
# Name: Age, dtype: float64

# %%
people
# Out:
#    Name   Age   Salary
# 0   Ali  25.0  50000.0
# 1  Sara  30.0      NaN
# 2  Reza   NaN  60000.0
# 3  Mina  28.0  55000.0

# %%
people["Age"] = people["Age"].fillna(people["Age"].mean())
people
# Out:
#    Name        Age   Salary
# 0   Ali  25.000000  50000.0
# 1  Sara  30.000000      NaN
# 2  Reza  27.666667  60000.0
# 3  Mina  28.000000  55000.0

# %%
people["Salary"] = people["Salary"].fillna(people["Salary"].mean())
people
# Out:
#    Name        Age   Salary
# 0   Ali  25.000000  50000.0
# 1  Sara  30.000000  55000.0
# 2  Reza  27.666667  60000.0
# 3  Mina  28.000000  55000.0

# %%
people.isnull().sum()
# Out:
# Name      0
# Age       0
# Salary    0
# dtype: int64

# %%
data = {
    "Name": ["Ali", "Sara", "Reza", "Mina"],
    "Age": [25, 30, None, 28],
    "Salary": [50000, None, 60000, 55000]
}

people = pd.DataFrame(data)

# %%
people
# Out:
#    Name   Age   Salary
# 0   Ali  25.0  50000.0
# 1  Sara  30.0      NaN
# 2  Reza   NaN  60000.0
# 3  Mina  28.0  55000.0

# %%
people.dropna()
# Out:
#    Name   Age   Salary
# 0   Ali  25.0  50000.0
# 3  Mina  28.0  55000.0

# %%
people
# Out:
#    Name   Age   Salary
# 0   Ali  25.0  50000.0
# 3  Mina  28.0  55000.0

# %%
people=people.dropna()

# %%
people.dropna(subset=["Age"])
# Out:
#    Name   Age   Salary
# 0   Ali  25.0  50000.0
# 1  Sara  30.0      NaN
# 3  Mina  28.0  55000.0

# %%
people.dropna(subset=["Salary"])
# Out:
#    Name   Age   Salary
# 0   Ali  25.0  50000.0
# 2  Reza   NaN  60000.0
# 3  Mina  28.0  55000.0

# %%
import pandas as pd

data = {
    "Year": [2019, 2020, 2021, 2022, 2023, 2024],
    "Laptop": [120, 150, 180, 210, 260, 310],
    "Phone": [200, 230, 190, 270, 320, 370],
    "Tablet": [80, 95, 110, 105, 140, 160]
}

df = pd.DataFrame(data)

df
# Out:
#    Year  Laptop  Phone  Tablet
# 0  2019     120    200      80
# 1  2020     150    230      95
# 2  2021     180    190     110
# 3  2022     210    270     105
# 4  2023     260    320     140
# 5  2024     310    370     160

# %%
df["Laptop"].max()
# Out:
# np.int64(310)

# %%
df["Tablet"].min()
# Out:
# np.int64(80)

# %%
df["Phone"].mean()
# Out:
# np.float64(263.3333333333333)

# %%
df["Laptop"].sum()
# Out:
# np.int64(1230)

# %%
df[df["Phone"] == df["Phone"].max()]
# Out:
#    Year  Laptop  Phone  Tablet
# 5  2024     310    370     160

# %%
df["Phone"].max()
# Out:
# np.int64(370)

# %%
df[df["Phone"] == df["Phone"].max()]
# Out:
#    Year  Laptop  Phone  Tablet
# 5  2024     310    370     160

# %%
df[df["Laptop"] == df["Laptop"].min()]
# Out:
#    Year  Laptop  Phone  Tablet
# 0  2019     120    200      80

# %%
df["Category"] = ["Low", "Low", "Medium", "Medium", "High", "High"]

df
# Out:
#    Year  Laptop  Phone  Tablet Category
# 0  2019     120    200      80      Low
# 1  2020     150    230      95      Low
# 2  2021     180    190     110   Medium
# 3  2022     210    270     105   Medium
# 4  2023     260    320     140     High
# 5  2024     310    370     160     High

# %%
df["Category"].value_counts()
# Out:
# Category
# Low       2
# Medium    2
# High      2
# Name: count, dtype: int64

# %%
df["Laptop"].value_counts()
# Out:
# Laptop
# 120    1
# 150    1
# 180    1
# 210    1
# 260    1
# 310    1
# Name: count, dtype: int64

# %%
df
# Out:
#    Year  Laptop  Phone  Tablet Category
# 0  2019     120    200      80      Low
# 1  2020     150    230      95      Low
# 2  2021     180    190     110   Medium
# 3  2022     210    270     105   Medium
# 4  2023     260    320     140     High
# 5  2024     310    370     160     High

# %%
df.groupby("Category")["Laptop"].mean()
# Out:
# Category
# High      285.0
# Low       135.0
# Medium    195.0
# Name: Laptop, dtype: float64

# %%
df.groupby("Category")["Laptop"].mean()
# Out:
# Category
# High      285.0
# Low       135.0
# Medium    195.0
# Name: Laptop, dtype: float64

# %%
df.groupby("Category")["Phone"].mean()
# Out:
# Category
# High      345.0
# Low       215.0
# Medium    230.0
# Name: Phone, dtype: float64

# %%
df.groupby("Category")["Tablet"].max()
# Out:
# Category
# High      160
# Low        95
# Medium    110
# Name: Tablet, dtype: int64

# %%
df.groupby("Category")[["Laptop", "Phone"]].mean()
# Out:
#           Laptop  Phone
# Category
# High       285.0  345.0
# Low        135.0  215.0
# Medium     195.0  230.0

# %%
df.groupby("Category")[["Tablet","Laptop"]].sum()
# Out:
#           Tablet  Laptop
# Category
# High         300     570
# Low          175     270
# Medium       215     390

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Year": [2018, 2019, 2020, 2021, 2022, 2023],
    "India": [1200, 1450, 1100, 1700, 2100, 2500],
    "Iran": [800, 950, 900, 1250, 1600, 1900],
    "Norway": [300, 350, 320, 400, 450, 500]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    Year  India  Iran  Norway
# 0  2018   1200   800     300
# 1  2019   1450   950     350
# 2  2020   1100   900     320
# 3  2021   1700  1250     400
# 4  2022   2100  1600     450
# 5  2023   2500  1900     500

# %%
df.plot(x="Year", y="India", kind="line")
plt.show()

# %%
df.plot (x="Year", y="Iran", kind="line")
plt.title("Immigration from Iran")
plt.xlabel("Year")
plt.ylabel("Number of Immigrants")
plt.show()

# %%
df.plot(x="Year", y=["Iran", "India", "Norway"], kind="line")
plt.title("Immigration from Iran, India and Norway to Canada")
plt.xlabel("Year")
plt.ylabel("Number of Immigrants")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Year": [2019, 2020, 2021, 2022, 2023, 2024],
    "Laptop": [120, 150, 180, 210, 260, 310],
    "Phone": [200, 230, 190, 270, 320, 370],
    "Tablet": [80, 95, 110, 105, 140, 160]
}

df = pd.DataFrame(data)

df["Phone"]
# Out:
# 0    200
# 1    230
# 2    190
# 3    270
# 4    320
# 5    370
# Name: Phone, dtype: int64

# %%
df
# Out:
#    Year  Laptop  Phone  Tablet
# 0  2019     120    200      80
# 1  2020     150    230      95
# 2  2021     180    190     110
# 3  2022     210    270     105
# 4  2023     260    320     140
# 5  2024     310    370     160

# %%
df[1:7]
# Out:
#    Year  Laptop  Phone  Tablet
# 1  2020     150    230      95
# 2  2021     180    190     110
# 3  2022     210    270     105
# 4  2023     260    320     140
# 5  2024     310    370     160

# %%
df[2:4]
# Out:
#    Year  Laptop  Phone  Tablet
# 2  2021     180    190     110
# 3  2022     210    270     105

# %%
df.plot(x="Year", y="Laptop", kind="line")
plt.title("laptop Sale per Year")
plt.xlabel("Year")
plt.ylabel("Sale")
plt.show()

# %%
df.plot(x="Year", y=["Laptop", "Phone", "Tablet"], kind="line")
plt.title("Product Sales by Year")
plt.xlabel("Year")
plt.ylabel("Sale")
plt.show()

# %%
df[df["Year"] == 2024]
# Out:
#    Year  Laptop  Phone  Tablet
# 5  2024     310    370     160

# %%
sales_2024 = df[df["Year"] == 2024]

# %%
products = ["Laptop", "Phone", "Tablet"]
sales = [310, 370, 160]

plt.bar(products, sales)
plt.title("Product Sales in 2024")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.show()

plt.bar(products, sales)
# Out:
# <BarContainer object of 3 artists>

# %%
sales_2024 = df[df["Year"] == 2024]

sales_2024[["Laptop", "Phone", "Tablet"]].iloc[0]
# Out:
# Laptop    310
# Phone     370
# Tablet    160
# Name: 5, dtype: int64

# %%
sales_2024[["Laptop", "Phone", "Tablet"]]
# Out:
#    Laptop  Phone  Tablet
# 5     310    370     160

# %%
sales_2024[["Laptop", "Phone", "Tablet"]].iloc[0]
# Out:
# Laptop    310
# Phone     370
# Tablet    160
# Name: 5, dtype: int64
